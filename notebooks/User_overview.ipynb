# %%
import os, sys
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
print(parent_dir)
sys.path.insert(0, parent_dir)
from scripts.user_overview import overview
# Out:
# c:\Users\hello\Desktop\git\Telecommunication-company-analysis

# %%
"""df=overview.load_data('SELECT * FROM xdr_data;')
df"""
file= 'C:/Users/hello/Desktop/Data/Copy of Week2_challenge_data_source(CSV).csv'
df=overview.load_data(file)
df
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN              NaN       NaN              NaN     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
#performing feature engieneering
df_edited= overview.handle_dataset(df)
df_edited
# Out:
#          index     Bearer Id            Start  Start ms              End  \
# 0            0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35
# 1            1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15
# 2            2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58
# 3            3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36
# 4            4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40
# ...        ...           ...              ...       ...              ...
# 148501  149995  1.304243e+19   4/29/2019 7:28     615.0   4/30/2019 0:01
# 148502  149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02
# 148503  149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41
# 148504  149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46
# 148505  149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40
#
#         End ms  Dur. (ms)          IMSI  MSISDN/Number          IMEI  ...  \
# ...

# %%
top_10,top_3= overview.handset(df_edited)
top_10,top_3
# Out:
# (Handset Type
#  Huawei B528S-23A                19727
#  Apple iPhone 6S (A1688)          9395
#  Apple iPhone 6 (A1586)           8993
#  undefined                        8904
#  Apple iPhone 7 (A1778)           6279
#  Apple iPhone Se (A1723)          5165
#  Apple iPhone 8 (A1905)           4977
#  Apple iPhone Xr (A2105)          4556
#  Samsung Galaxy S8 (Sm-G950F)     4464
#  Apple iPhone X (A1901)           3806
#  Name: count, dtype: int64,
#  Handset Manufacturer
#  Apple      59339
#  Samsung    40429
#  Huawei     34296
#  Name: count, dtype: int64)

# %%
per_user=overview.aggregation_per_user(df_edited)
per_user
# Out:
#            Bearer Id  number_of_sessions  total_session_duration  \
# 0       6.917538e+18                   1                 24534.0
# 1       6.917538e+18                   1                 21489.0
# 2       6.917538e+18                   1                 27786.0
# 3       6.917538e+18                   1                 15635.0
# 4       6.917538e+18                   1                 24264.0
# ...              ...                 ...                     ...
# 134250  1.318654e+19                   1                 80024.0
# 134251  1.318654e+19                   1                145291.0
# 134252  1.318654e+19                   1                 86399.0
# 134253  1.318654e+19                   1                 86399.0
# 134254  1.318654e+19                   1                103113.0
#
#         total_download_data  total_upload_data  total_data_volume_netflix  \
# 0               500721999.0         41704610.0                 34162632.0
# ...

# %%
decile=overview.user_segementation(df_edited)
decile
# Out:
#    Decile     Dur. (ms)    Total Data
# 0       1  2.964438e+08  7.368647e+12
# 1       2  5.439634e+08  7.365871e+12
# 2       3  8.730336e+08  7.404380e+12
# 4       5  1.115131e+09  6.289253e+12
# 5       6  1.528953e+09  7.367847e+12
# 6       7  1.972809e+09  7.334330e+12
# 7       8  2.446986e+09  7.384466e+12
# 3       4  2.715525e+09  1.572192e+13
# 8       9  4.112767e+09  7.390093e+12

# %%
disperation=overview.compute_dispersion(df_edited)
disperation
# Out:
#                             index  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# Mean                 7.515415e+04       106.869090        17.634676
# Median               7.506350e+04        54.000000         7.000000
# Variance             1.873056e+09    280514.931768      5847.517037
# Standard Deviation   4.327882e+04       529.636604        76.469059
# Range                1.499990e+05     96923.000000      7120.000000
# Interquartile Range  7.488750e+04        74.795706        14.662883
#
#                      Avg Bearer TP DL (kbps)  Avg Bearer TP UL (kbps)  \
# Mean                            1.328752e+04             1.770598e+03
# Median                          6.300000e+01             6.200000e+01
# Variance                        5.756870e+08             2.143973e+07
# Standard Deviation              2.399348e+04             4.630306e+03
# Range                           3.781600e+05             5.861300e+04
# ...

# %%
univariate=overview.uni(df_edited)
univariate

# %%
bivariate=overview.bi(df)
bivariate

# %%
corr=overview.correlation(df_edited)
corr

# %%
pca= overview.PCAA(df_edited)
pca
